# %% [markdown]
# # 🎮 DQN Agent — Demon Attack (Atari)
# **Environment:** ALE/DemonAttack-v5
# **Framework:** Stable Baselines3 + Gymnasium
#
# > ⚠️ Before running: Go to **Runtime → Change runtime type → T4 GPU → Save**

# %%
# ── Cell 1: Install Dependencies ─────────────────────────────
# !pip install -q stable-baselines3[extra] gymnasium[atari,accept-rom-license] ale-py matplotlib
# !pip install -q autorom[accept-rom-license]
# !AutoROM --accept-license
print("\n✔ All dependencies installed!")
# Out:
# WARNING: gymnasium 1.2.3 does not provide the extra 'accept-rom-license'
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.0/188.0 kB 14.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 33.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# AutoROM will download the Atari 2600 ROMs.
# They will be installed to:
# 	/usr/local/lib/python3.12/dist-packages/AutoROM/roms
#
# Existing ROMs will be overwritten.
#
# ✔ All dependencies installed!

# %%
# ── Cell 2: Mount Google Drive ───────────────────────────────
# Saves model safely to Drive in case session disconnects
from google.colab import drive
import os

drive.mount('/content/drive')

SAVE_DIR = '/content/drive/MyDrive/DemonAttack_DQN'
os.makedirs(SAVE_DIR, exist_ok=True)
print(f"✔ Drive mounted! Files will be saved to: {SAVE_DIR}")
# Out:
# Mounted at /content/drive
# ✔ Drive mounted! Files will be saved to: /content/drive/MyDrive/DemonAttack_DQN

# %%
# ── Cell 3: Upload train.py then Run Training ─────────────────
# Make sure train.py is uploaded in the Files panel on the left!
# !python train.py
# Out:
# Streaming output truncated to the last 5000 lines.
#   Ep  330 | Reward:     0.00 | Length:      6
#   Ep  331 | Reward:     2.00 | Length:     31
#   Ep  332 | Reward:     1.00 | Length:      5
#   Ep  333 | Reward:     9.00 | Length:    136
#   Ep  334 | Reward:     1.00 | Length:     31
#   Ep  335 | Reward:     0.00 | Length:      6
#   Ep  336 | Reward:     7.00 | Length:    128
#   Ep  337 | Reward:     1.00 | Length:     14
#   Ep  338 | Reward:     1.00 | Length:     13
#   Ep  339 | Reward:     3.00 | Length:     72
#   Ep  340 | Reward:     1.00 | Length:     16
#   Ep  341 | Reward:     2.00 | Length:     39
#   Ep  342 | Reward:     3.00 | Length:     42
#   Ep  343 | Reward:     3.00 | Length:     29
#   Ep  344 | Reward:     0.00 | Length:      7
#   Ep  345 | Reward:     4.00 | Length:     66
#   Ep  346 | Reward:     1.00 | Length:      9
#   Ep  347 | Reward:     4.00 | Length:     22
#   Ep  348 | Reward:    10.00 | Length:    112
# ...

# %%
# ── Cell 4: Copy outputs to Google Drive ─────────────────────
import shutil, os

SAVE_DIR = '/content/drive/MyDrive/DemonAttack_DQN'
files_to_save = [
    'dqn_model.zip',
    'training_rewards.png',
    'all_experiments.png',
    'experiment_results.txt'
]

for f in files_to_save:
    if os.path.exists(f):
        shutil.copy(f, os.path.join(SAVE_DIR, f))
        print(f"✔ Saved to Drive: {f}")
    else:
        print(f"✘ Not found: {f}")

print(f"\n✔ All files backed up to Google Drive → {SAVE_DIR}")
# Out:
# ✔ Saved to Drive: dqn_model.zip
# ✔ Saved to Drive: training_rewards.png
# ✔ Saved to Drive: all_experiments.png
# ✔ Saved to Drive: experiment_results.txt
#
# ✔ All files backed up to Google Drive → /content/drive/MyDrive/DemonAttack_DQN

# %%
# ── Cell 5: Download files to your computer ───────────────────
from google.colab import files
import os

files_to_download = [
    'dqn_model.zip',
    'training_rewards.png',
    'all_experiments.png',
    'experiment_results.txt'
]

for f in files_to_download:
    if os.path.exists(f):
        files.download(f)
        print(f"✔ Downloading: {f}")
    else:
        print(f"✘ Not found: {f}")
# Out:
# ✔ Downloading: dqn_model.zip
# ✔ Downloading: training_rewards.png
# ✔ Downloading: all_experiments.png
# ✔ Downloading: experiment_results.txt
